# %% [markdown]
# <a href="https://colab.research.google.com/github/Aliyahk888/GAN-based-Image-Restoration-and-Colourization/blob/main/Combined_with_SRGan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras import layers, Model
from sklearn.model_selection import train_test_split

import numpy as np
from keras import Model
from keras.layers import Conv2D, PReLU,BatchNormalization, Flatten
from keras.layers import UpSampling2D, LeakyReLU, Dense, Input, add
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/Image_data/dataset.zip
# Out:
# Archive:  /content/drive/MyDrive/Image_data/dataset.zip
#   inflating: data/24322.jpg
#   inflating: data/24315.jpg
#   inflating: data/24321.jpg
#   inflating: data/24269.jpg
#   inflating: data/24301.jpg
#   inflating: data/24294.jpg
#   inflating: data/24304.jpg
#   inflating: data/24334.jpg
#   inflating: data/24329.jpg
#   inflating: data/24300.jpg
#   inflating: data/24325.jpg
#   inflating: data/24324.jpg
#   inflating: data/24319.jpg
#   inflating: data/24317.jpg
#   inflating: data/24328.jpg
#   inflating: data/24309.jpg
#   inflating: data/24297.jpg
#   inflating: data/24290.jpg
#   inflating: data/24332.jpg
#   inflating: data/24310.jpg
#   inflating: data/24323.jpg
#   inflating: data/24279.jpg
#   inflating: data/24282.jpg
#   inflating: data/24265.jpg
#   inflating: data/24264.jpg
#   inflating: data/24311.jpg
#   inflating: data/24314.jpg
#   inflating: data/24277.jpg
#   inflating: data/24262.jpg
#   inflating: data/24266.jpg
#   inflating: data/24273.jpg
#   inflating: data/24286.jpg
#   inflating: data/24312.jpg
#   inflating: data/24280.jpg
#   inflating: data/24263.jpg
#   inflating: data/24223.jpg
#   inflating: data/24252.jpg
#   inflating: data/24231.jpg
#   inflating: data/24268.jpg
#   inflating: data/24241.jpg
#   inflating: data/24261.jpg
#   inflating: data/24226.jpg
#   inflating: data/24285.jpg
#   inflating: data/24275.jpg
#   inflating: data/24239.jpg
#   inflating: data/24283.jpg
#   inflating: data/24284.jpg
#   inflating: data/24235.jpg
#   inflating: data/24237.jpg
#   inflating: data/24250.jpg
#   inflating: data/24229.jpg
#   inflating: data/24244.jpg
#   inflating: data/24254.jpg
#   inflating: data/24230.jpg
#   inflating: data/24248.jpg
#   inflating: data/24251.jpg
#   inflating: data/24236.jpg
#   inflating: data/24228.jpg
#   inflating: data/24224.jpg
#   inflating: data/24249.jpg
#   inflating: data/24271.jpg
#   inflating: data/24242.jpg
#   inflating: data/24205.jpg
#   inflating: data/24193.jpg
#   inflating: data/24245.jpg
#   inflating: data/24199.jpg
#   inflating: data/24211.jpg
#   inflating: data/24258.jpg
#   inflating: data/24256.jpg
#   inflating: data/24186.jpg
#   inflating: data/24190.jpg
#   inflating: data/24185.jpg
#   inflating: data/24247.jpg
#   inflating: data/24215.jpg
#   inflating: data/24200.jpg
#   inflating: data/24219.jpg
#   inflating: data/24260.jpg
#   inflating: data/24198.jpg
#   inflating: data/24201.jpg
#   inflating: data/24197.jpg
#   inflating: data/24313.jpg
#   inflating: data/24218.jpg
#   inflating: data/24187.jpg
#   inflating: data/24220.jpg
#   inflating: data/24207.jpg
#   inflating: data/24153.jpg
#   inflating: data/24287.jpg
#   inflating: data/24189.jpg
#   inflating: data/24195.jpg
#   inflating: data/24270.jpg
#   inflating: data/24159.jpg
#   inflating: data/24176.jpg
#   inflating: data/24213.jpg
#   inflating: data/24158.jpg
#   inflating: data/24204.jpg
#   inflating: data/24172.jpg
#   inflating: data/24152.jpg
#   inflating: data/24161.jpg
#   inflating: data/24212.jpg
#   inflating: data/24178.jpg
#   inflating: data/24175.jpg
#   inflating: data/24206.jpg
#   inflating: data/24154.jpg
#   inflating: data/24179.jpg
#   inflating: data/24169.jpg
#   inflating: data/24167.jpg
#   inflating: data/24184.jpg
#   inflating: data/24173.jpg
#   inflating: data/24160.jpg
#   inflating: data/24170.jpg
#   inflating: data/24163.jpg
#   inflating: data/24150.jpg
#   inflating: data/24155.jpg
#   inflating: data/24180.jpg
#   inflating: data/24122.jpg
#   inflating: data/24112.jpg
#   inflating: data/24171.jpg
#   inflating: data/24147.jpg
#   inflating: data/24139.jpg
#   inflating: data/24181.jpg
#   inflating: data/24295.jpg
#   inflating: data/24118.jpg
#   inflating: data/24136.jpg
#   inflating: data/24132.jpg
#   inflating: data/24127.jpg
#   inflating: data/24222.jpg
#   inflating: data/24208.jpg
#   inflating: data/24113.jpg
#   inflating: data/24119.jpg
#   inflating: data/24111.jpg
#   inflating: data/24177.jpg
#   inflating: data/24124.jpg
#   inflating: data/24143.jpg
#   inflating: data/24115.jpg
#   inflating: data/24131.jpg
#   inflating: data/24274.jpg
#   inflating: data/24146.jpg
#   inflating: data/24128.jpg
#   inflating: data/24135.jpg
#   inflating: data/24123.jpg
#   inflating: data/24137.jpg
#   inflating: data/24246.jpg
#   inflating: data/24101.jpg
#   inflating: data/24234.jpg
#   inflating: data/24097.jpg
#   inflating: data/24098.jpg
#   inflating: data/24106.jpg
#   inflating: data/24129.jpg
#   inflating: data/24120.jpg
#   inflating: data/24141.jpg
#   inflating: data/24130.jpg
#   inflating: data/24100.jpg
#   inflating: data/24203.jpg
#   inflating: data/24108.jpg
#   inflating: data/24196.jpg
#   inflating: data/24088.jpg
#   inflating: data/24174.jpg
#   inflating: data/24109.jpg
#   inflating: data/24110.jpg
#   inflating: data/24095.jpg
#   inflating: data/24091.jpg
#   inflating: data/24099.jpg
#   inflating: data/24299.jpg
#   inflating: data/24086.jpg
#   inflating: data/24094.jpg
#   inflating: data/24073.jpg
#   inflating: data/24166.jpg
#   inflating: data/24047.jpg
#   inflating: data/24053.jpg
#   inflating: data/24221.jpg
#   inflating: data/24096.jpg
#   inflating: data/24070.jpg
#   inflating: data/24087.jpg
#   inflating: data/24072.jpg
#   inflating: data/24055.jpg
#   inflating: data/24057.jpg
#   inflating: data/24080.jpg
#   inflating: data/24039.jpg
#   inflating: data/24060.jpg
#   inflating: data/24209.jpg
#   inflating: data/24040.jpg
#   inflating: data/24063.jpg
#   inflating: data/24044.jpg
#   inflating: data/24059.jpg
#   inflating: data/24066.jpg
#   inflating: data/24083.jpg
#   inflating: data/24051.jpg
#   inflating: data/24041.jpg
#   inflating: data/24056.jpg
#   inflating: data/24138.jpg
#   inflating: data/24062.jpg
#   inflating: data/24076.jpg
#   inflating: data/24085.jpg
#   inflating: data/24052.jpg
#   inflating: data/24126.jpg
#   inflating: data/24004.jpg
#   inflating: data/24075.jpg
#   inflating: data/24045.jpg
#   inflating: data/24020.jpg
#   inflating: data/24058.jpg
#   inflating: data/24103.jpg
#   inflating: data/24050.jpg
#   inflating: data/24018.jpg
#   inflating: data/23997.jpg
#   inflating: data/24001.jpg
#   inflating: data/24011.jpg
#   inflating: data/24034.jpg
#   inflating: data/24019.jpg
#   inflating: data/24009.jpg
#   inflating: data/24149.jpg
#   inflating: data/24214.jpg
#   inflating: data/24078.jpg
#   inflating: data/24007.jpg
#   inflating: data/24320.jpg
#   inflating: data/24021.jpg
#   inflating: data/24022.jpg
#   inflating: data/24005.jpg
#   inflating: data/24023.jpg
#   inflating: data/24107.jpg
#   inflating: data/24036.jpg
#   inflating: data/24032.jpg
#   inflating: data/24017.jpg
#   inflating: data/24027.jpg
#   inflating: data/24013.jpg
#   inflating: data/24145.jpg
#   inflating: data/24267.jpg
#   inflating: data/24165.jpg
#   inflating: data/24016.jpg
#   inflating: data/24024.jpg
#   inflating: data/24049.jpg
#   inflating: data/24010.jpg
#   inflating: data/24037.jpg
#   inflating: data/23989.jpg
#   inflating: data/23951.jpg
#   inflating: data/24292.jpg
#   inflating: data/24008.jpg
#   inflating: data/23959.jpg
#   inflating: data/23952.jpg
#   inflating: data/24033.jpg
#   inflating: data/24029.jpg
#   inflating: data/23986.jpg
#   inflating: data/23998.jpg
#   inflating: data/24077.jpg
#   inflating: data/23990.jpg
#   inflating: data/24000.jpg
#   inflating: data/24006.jpg
#   inflating: data/24133.jpg
#   inflating: data/24043.jpg
#   inflating: data/24082.jpg
#   inflating: data/24026.jpg
#   inflating: data/23984.jpg
#   inflating: data/23969.jpg
#   inflating: data/23961.jpg
#   inflating: data/23976.jpg
#   inflating: data/23979.jpg
#   inflating: data/23981.jpg
#   inflating: data/23995.jpg
#   inflating: data/23955.jpg
#   inflating: data/23965.jpg
#   inflating: data/23950.jpg
#   inflating: data/23974.jpg
#   inflating: data/23988.jpg
#   inflating: data/23956.jpg
#   inflating: data/23977.jpg
#   inflating: data/23967.jpg
#   inflating: data/23962.jpg
#   inflating: data/23993.jpg
#   inflating: data/23964.jpg
#   inflating: data/23972.jpg
#   inflating: data/23978.jpg
#   inflating: data/23932.jpg
#   inflating: data/23975.jpg
#   inflating: data/23947.jpg
#   inflating: data/23923.jpg
#   inflating: data/23949.jpg
#   inflating: data/23909.jpg
#   inflating: data/23907.jpg
#   inflating: data/23982.jpg
#   inflating: data/23928.jpg
#   inflating: data/23958.jpg
#   inflating: data/23920.jpg
#   inflating: data/23945.jpg
#   inflating: data/23927.jpg
#   inflating: data/23918.jpg
#   inflating: data/23948.jpg
#   inflating: data/23926.jpg
#   inflating: data/23915.jpg
#   inflating: data/23943.jpg
#   inflating: data/23925.jpg
#   inflating: data/23912.jpg
#   inflating: data/23939.jpg
#   inflating: data/23935.jpg
#   inflating: data/23910.jpg
#   inflating: data/23938.jpg
#   inflating: data/23929.jpg
#   inflating: data/23937.jpg
#   inflating: data/23919.jpg
#   inflating: data/23987.jpg
#   inflating: data/23930.jpg
#   inflating: data/23908.jpg
#   inflating: data/23942.jpg
#   inflating: data/23885.jpg
#   inflating: data/23890.jpg
#   inflating: data/23886.jpg
#   inflating: data/23877.jpg
#   inflating: data/23933.jpg
#   inflating: data/23889.jpg
#   inflating: data/23899.jpg
#   inflating: data/23901.jpg
#   inflating: data/23888.jpg
#   inflating: data/23884.jpg
#   inflating: data/23906.jpg
#   inflating: data/23862.jpg
#   inflating: data/23883.jpg
#   inflating: data/23892.jpg
#   inflating: data/23896.jpg
#   inflating: data/23874.jpg
#   inflating: data/23968.jpg
#   inflating: data/23898.jpg
#   inflating: data/23903.jpg
#   inflating: data/23869.jpg
#   inflating: data/23867.jpg
#   inflating: data/23868.jpg
#   inflating: data/23871.jpg
#   inflating: data/23876.jpg
#   inflating: data/23875.jpg
#   inflating: data/23872.jpg
#   inflating: data/23822.jpg
#   inflating: data/23900.jpg
#   inflating: data/23829.jpg
#   inflating: data/23866.jpg
#   inflating: data/23973.jpg
#   inflating: data/23853.jpg
#   inflating: data/23859.jpg
#   inflating: data/23870.jpg
#   inflating: data/23848.jpg
#   inflating: data/23865.jpg
#   inflating: data/23855.jpg
#   inflating: data/23821.jpg
#   inflating: data/23835.jpg
#   inflating: data/23843.jpg
#   inflating: data/23826.jpg
#   inflating: data/23846.jpg
#   inflating: data/23833.jpg
#   inflating: data/23841.jpg
#   inflating: data/23854.jpg
#   inflating: data/23852.jpg
#   inflating: data/23838.jpg
#   inflating: data/23837.jpg
#   inflating: data/23819.jpg
#   inflating: data/23830.jpg
#   inflating: data/23845.jpg
#   inflating: data/23806.jpg
#   inflating: data/23817.jpg
#   inflating: data/23786.jpg
#   inflating: data/23936.jpg
#   inflating: data/23860.jpg
#   inflating: data/23816.jpg
#   inflating: data/23783.jpg
#   inflating: data/23807.jpg
#   inflating: data/23793.jpg
#   inflating: data/23797.jpg
#   inflating: data/23794.jpg
#   inflating: data/23801.jpg
#   inflating: data/23792.jpg
#   inflating: data/23804.jpg
#   inflating: data/23810.jpg
#   inflating: data/23818.jpg
#   inflating: data/23902.jpg
#   inflating: data/23791.jpg
#   inflating: data/23808.jpg
#   inflating: data/23814.jpg
#   inflating: data/23813.jpg
#   inflating: data/23931.jpg
#   inflating: data/23776.jpg
#   inflating: data/23812.jpg
#   inflating: data/23774.jpg
#   inflating: data/23795.jpg
#   inflating: data/23761.jpg
#   inflating: data/23759.jpg
#   inflating: data/23798.jpg
#   inflating: data/23757.jpg
#   inflating: data/23815.jpg
#   inflating: data/23745.jpg
#   inflating: data/23747.jpg
#   inflating: data/23753.jpg
#   inflating: data/23781.jpg
#   inflating: data/23764.jpg
#   inflating: data/23771.jpg
#   inflating: data/23773.jpg
#   inflating: data/23748.jpg
#   inflating: data/23775.jpg
#   inflating: data/23750.jpg
#   inflating: data/23762.jpg
#   inflating: data/23756.jpg
#   inflating: data/23766.jpg
#   inflating: data/23743.jpg
#   inflating: data/23782.jpg
#   inflating: data/23779.jpg
#   inflating: data/23744.jpg
#   inflating: data/23760.jpg
#   inflating: data/23741.jpg
#   inflating: data/23749.jpg
#   inflating: data/23727.jpg
#   inflating: data/23879.jpg
#   inflating: data/23708.jpg
#   inflating: data/23738.jpg
#   inflating: data/23726.jpg
#   inflating: data/23724.jpg
#   inflating: data/23711.jpg
#   inflating: data/23725.jpg
#   inflating: data/23716.jpg
#   inflating: data/23729.jpg
#   inflating: data/23714.jpg
#   inflating: data/23736.jpg
#   inflating: data/23709.jpg
#   inflating: data/23723.jpg
#   inflating: data/23851.jpg
#   inflating: data/23746.jpg
#   inflating: data/23717.jpg
#   inflating: data/23861.jpg
#   inflating: data/23710.jpg
#   inflating: data/23713.jpg
#   inflating: data/23731.jpg
#   inflating: data/23739.jpg
#   inflating: data/23703.jpg
#   inflating: data/23737.jpg
#   inflating: data/23733.jpg
#   inflating: data/23688.jpg
#   inflating: data/23695.jpg
#   inflating: data/23707.jpg
#   inflating: data/23697.jpg
#   inflating: data/23721.jpg
#   inflating: data/23728.jpg
#   inflating: data/23734.jpg
#   inflating: data/23705.jpg
#   inflating: data/23718.jpg
#   inflating: data/23694.jpg
#   inflating: data/23698.jpg
#   inflating: data/23702.jpg
#   inflating: data/23684.jpg
#   inflating: data/23656.jpg
#   inflating: data/23692.jpg
#   inflating: data/23653.jpg
#   inflating: data/23735.jpg
#   inflating: data/23649.jpg
#   inflating: data/23643.jpg
#   inflating: data/23657.jpg
#   inflating: data/23677.jpg
#   inflating: data/23687.jpg
#   inflating: data/23648.jpg
#   inflating: data/23682.jpg
#   inflating: data/23675.jpg
#   inflating: data/23676.jpg
#   inflating: data/23644.jpg
#   inflating: data/23642.jpg
#   inflating: data/23686.jpg
#   inflating: data/23660.jpg
#   inflating: data/23668.jpg
#   inflating: data/23658.jpg
#   inflating: data/23667.jpg
#   inflating: data/23689.jpg
#   inflating: data/23683.jpg
#   inflating: data/23669.jpg
#   inflating: data/23679.jpg
#   inflating: data/23652.jpg
#   inflating: data/23663.jpg
#   inflating: data/23659.jpg
#   inflating: data/23639.jpg
#   inflating: data/23681.jpg
#   inflating: data/23617.jpg
#   inflating: data/23655.jpg
#   inflating: data/23636.jpg
#   inflating: data/23640.jpg
#   inflating: data/23616.jpg
#   inflating: data/23785.jpg
#   inflating: data/23873.jpg
#   inflating: data/23641.jpg
#   inflating: data/23613.jpg
#   inflating: data/23625.jpg
#   inflating: data/23647.jpg
#   inflating: data/23632.jpg
#   inflating: data/23628.jpg
#   inflating: data/23633.jpg
#   inflating: data/23609.jpg
#   inflating: data/23600.jpg
#   inflating: data/23620.jpg
#   inflating: data/23635.jpg
#   inflating: data/23594.jpg
#   inflating: data/23712.jpg
#   inflating: data/23769.jpg
#   inflating: data/23715.jpg
#   inflating: data/23796.jpg
#   inflating: data/23825.jpg
#   inflating: data/23604.jpg
#   inflating: data/23780.jpg
#   inflating: data/23678.jpg
#   inflating: data/23758.jpg
#   inflating: data/23700.jpg
#   inflating: data/23552.jpg
#   inflating: data/23610.jpg
#   inflating: data/23597.jpg
#   inflating: data/23549.jpg
#   inflating: data/23623.jpg
#   inflating: data/23606.jpg
#   inflating: data/23593.jpg
#   inflating: data/23574.jpg
#   inflating: data/23550.jpg
#   inflating: data/23619.jpg
#   inflating: data/23585.jpg
#   inflating: data/23591.jpg
#   inflating: data/23575.jpg
#   inflating: data/23638.jpg
#   inflating: data/23630.jpg
#   inflating: data/23637.jpg
#   inflating: data/23629.jpg
#   inflating: data/23557.jpg
#   inflating: data/23559.jpg
#   inflating: data/23562.jpg
#   inflating: data/23573.jpg
#   inflating: data/23570.jpg
#   inflating: data/23551.jpg
#   inflating: data/23505.jpg
#   inflating: data/23565.jpg
#   inflating: data/23588.jpg
#   inflating: data/23564.jpg
#   inflating: data/23586.jpg
#   inflating: data/23611.jpg
#   inflating: data/23589.jpg
#   inflating: data/23608.jpg
#   inflating: data/23590.jpg
#   inflating: data/23612.jpg
#   inflating: data/23577.jpg
#   inflating: data/23587.jpg
#   inflating: data/23548.jpg
#   inflating: data/23507.jpg
#   inflating: data/23538.jpg
#   inflating: data/23515.jpg
#   inflating: data/23598.jpg
#   inflating: data/23537.jpg
#   inflating: data/23536.jpg
#   inflating: data/23530.jpg
#   inflating: data/23499.jpg
#   inflating: data/23509.jpg
#   inflating: data/23512.jpg
#   inflating: data/23534.jpg
#   inflating: data/23584.jpg
#   inflating: data/23567.jpg
#   inflating: data/23603.jpg
#   inflating: data/23510.jpg
#   inflating: data/23560.jpg
#   inflating: data/23578.jpg
#   inflating: data/23541.jpg
#   inflating: data/23496.jpg
#   inflating: data/23527.jpg
#   inflating: data/23529.jpg
#   inflating: data/23576.jpg
#   inflating: data/23503.jpg
#   inflating: data/23542.jpg
#   inflating: data/23543.jpg
#   inflating: data/23502.jpg
#   inflating: data/23528.jpg
#   inflating: data/23555.jpg
#   inflating: data/23495.jpg
#   inflating: data/23516.jpg
#   inflating: data/23531.jpg
#   inflating: data/23471.jpg
#   inflating: data/23476.jpg
#   inflating: data/23511.jpg
#   inflating: data/23472.jpg
#   inflating: data/23469.jpg
#   inflating: data/23535.jpg
#   inflating: data/23484.jpg
#   inflating: data/23470.jpg
#   inflating: data/23437.jpg
#   inflating: data/23481.jpg
#   inflating: data/23456.jpg
#   inflating: data/23463.jpg
#   inflating: data/23429.jpg
#   inflating: data/23490.jpg
#   inflating: data/23497.jpg
#   inflating: data/23521.jpg
#   inflating: data/23498.jpg
#   inflating: data/23487.jpg
#   inflating: data/23492.jpg
#   inflating: data/23446.jpg
#   inflating: data/23453.jpg
#   inflating: data/23465.jpg
#   inflating: data/23458.jpg
#   inflating: data/23444.jpg
#   inflating: data/23554.jpg
#   inflating: data/23489.jpg
#   inflating: data/23491.jpg
#   inflating: data/23477.jpg
#   inflating: data/23478.jpg
#   inflating: data/23474.jpg
#   inflating: data/23473.jpg
#   inflating: data/23540.jpg
#   inflating: data/23445.jpg
#   inflating: data/23443.jpg
#   inflating: data/23441.jpg
#   inflating: data/23436.jpg
#   inflating: data/23452.jpg
#   inflating: data/23466.jpg
#   inflating: data/23475.jpg
#   inflating: data/23486.jpg
#   inflating: data/23435.jpg
#   inflating: data/23431.jpg
#   inflating: data/23430.jpg
#   inflating: data/23428.jpg
#   inflating: data/23451.jpg
#   inflating: data/23450.jpg
#   inflating: data/23432.jpg
#   inflating: data/23455.jpg
#   inflating: data/23406.jpg
#   inflating: data/23433.jpg
#   inflating: data/23404.jpg
#   inflating: data/23624.jpg
#   inflating: data/23417.jpg
#   inflating: data/23579.jpg
#   inflating: data/23447.jpg
#   inflating: data/23457.jpg
#   inflating: data/23413.jpg
#   inflating: data/23442.jpg
#   inflating: data/23419.jpg
#   inflating: data/23393.jpg
#   inflating: data/23420.jpg
#   inflating: data/23405.jpg
#   inflating: data/23390.jpg
#   inflating: data/23418.jpg
#   inflating: data/23407.jpg
#   inflating: data/23386.jpg
#   inflating: data/23381.jpg
#   inflating: data/23401.jpg
#   inflating: data/23464.jpg
#   inflating: data/23392.jpg
#   inflating: data/23375.jpg
#   inflating: data/23370.jpg
#   inflating: data/23367.jpg
#   inflating: data/23402.jpg
#   inflating: data/23459.jpg
#   inflating: data/23408.jpg
#   inflating: data/23421.jpg
#   inflating: data/23411.jpg
#   inflating: data/23388.jpg
#   inflating: data/23398.jpg
#   inflating: data/23389.jpg
#   inflating: data/23423.jpg
#   inflating: data/23448.jpg
#   inflating: data/23371.jpg
#   inflating: data/23376.jpg
#   inflating: data/23380.jpg
#   inflating: data/23373.jpg
#   inflating: data/23384.jpg
#   inflating: data/23385.jpg
#   inflating: data/23383.jpg
#   inflating: data/23382.jpg
#   inflating: data/23427.jpg
#   inflating: data/23522.jpg
#   inflating: data/23377.jpg
#   inflating: data/23400.jpg
#   inflating: data/23339.jpg
#   inflating: data/23359.jpg
#   inflating: data/23337.jpg
#   inflating: data/23387.jpg
#   inflating: data/23349.jpg
#   inflating: data/23366.jpg
#   inflating: data/23320.jpg
#   inflating: data/23344.jpg
#   inflating: data/23333.jpg
#   inflating: data/23363.jpg
#   inflating: data/23353.jpg
#   inflating: data/23368.jpg
#   inflating: data/23661.jpg
#   inflating: data/23322.jpg
#   inflating: data/23321.jpg
#   inflating: data/23362.jpg
#   inflating: data/23329.jpg
#   inflating: data/23547.jpg
#   inflating: data/23328.jpg
#   inflating: data/23346.jpg
#   inflating: data/23334.jpg
#   inflating: data/23324.jpg
#   inflating: data/23325.jpg
#   inflating: data/23338.jpg
#   inflating: data/23343.jpg
#   inflating: data/23361.jpg
#   inflating: data/23318.jpg
#   inflating: data/23355.jpg
#   inflating: data/23312.jpg
#   inflating: data/23298.jpg
#   inflating: data/23299.jpg
#   inflating: data/23327.jpg
#   inflating: data/23461.jpg
#   inflating: data/23365.jpg
#   inflating: data/23348.jpg
#   inflating: data/23293.jpg
#   inflating: data/23317.jpg
#   inflating: data/23360.jpg
#   inflating: data/23301.jpg
#   inflating: data/23342.jpg
#   inflating: data/23290.jpg
#   inflating: data/23309.jpg
#   inflating: data/23291.jpg
#   inflating: data/23306.jpg
#   inflating: data/23310.jpg
#   inflating: data/23336.jpg
#   inflating: data/23294.jpg
#   inflating: data/23296.jpg
#   inflating: data/23315.jpg
#   inflating: data/23295.jpg
#   inflating: data/23248.jpg
#   inflating: data/23287.jpg
#   inflating: data/23283.jpg
#   inflating: data/23292.jpg
#   inflating: data/23297.jpg
#   inflating: data/23254.jpg
#   inflating: data/23308.jpg
#   inflating: data/23304.jpg
#   inflating: data/23271.jpg
#   inflating: data/23268.jpg
#   inflating: data/23274.jpg
#   inflating: data/23462.jpg
#   inflating: data/23261.jpg
#   inflating: data/23316.jpg
#   inflating: data/23260.jpg
#   inflating: data/23255.jpg
#   inflating: data/23273.jpg
#   inflating: data/23257.jpg
#   inflating: data/23253.jpg
#   inflating: data/23281.jpg
#   inflating: data/23289.jpg
#   inflating: data/23259.jpg
#   inflating: data/23275.jpg
#   inflating: data/23277.jpg
#   inflating: data/23262.jpg
#   inflating: data/23369.jpg
#   inflating: data/23416.jpg
#   inflating: data/23351.jpg
#   inflating: data/23332.jpg
#   inflating: data/23563.jpg
#   inflating: data/23319.jpg
#   inflating: data/23256.jpg
#   inflating: data/23314.jpg
#   inflating: data/23284.jpg
#   inflating: data/23596.jpg
#   inflating: data/23520.jpg
#   inflating: data/23454.jpg
#   inflating: data/23409.jpg
#   inflating: data/23270.jpg
#   inflating: data/23250.jpg
#   inflating: data/23233.jpg
#   inflating: data/23219.jpg
#   inflating: data/23247.jpg
#   inflating: data/23222.jpg
#   inflating: data/23272.jpg
#   inflating: data/23240.jpg
#   inflating: data/23269.jpg
#   inflating: data/23263.jpg
#   inflating: data/23218.jpg
#   inflating: data/23230.jpg
#   inflating: data/23237.jpg
#   inflating: data/23266.jpg
#   inflating: data/23221.jpg
#   inflating: data/23244.jpg
#   inflating: data/23227.jpg
#   inflating: data/23265.jpg
#   inflating: data/23224.jpg
#   inflating: data/23280.jpg
#   inflating: data/23245.jpg
#   inflating: data/23241.jpg
#   inflating: data/23223.jpg
#   inflating: data/23242.jpg
#   inflating: data/23213.jpg
#   inflating: data/23188.jpg
#   inflating: data/23210.jpg
#   inflating: data/23229.jpg
#   inflating: data/23232.jpg
#   inflating: data/23276.jpg
#   inflating: data/23234.jpg
#   inflating: data/23225.jpg
#   inflating: data/23215.jpg
#   inflating: data/23194.jpg
#   inflating: data/23220.jpg
#   inflating: data/23209.jpg
#   inflating: data/23192.jpg
#   inflating: data/23211.jpg
#   inflating: data/23243.jpg
#   inflating: data/23208.jpg
#   inflating: data/23179.jpg
#   inflating: data/23176.jpg
#   inflating: data/23180.jpg
#   inflating: data/23246.jpg
#   inflating: data/23236.jpg
#   inflating: data/23193.jpg
#   inflating: data/23205.jpg
#   inflating: data/23201.jpg
#   inflating: data/23212.jpg
#   inflating: data/23195.jpg
#   inflating: data/23207.jpg
#   inflating: data/23187.jpg
#   inflating: data/23186.jpg
#   inflating: data/23183.jpg
#   inflating: data/23165.jpg
#   inflating: data/23177.jpg
#   inflating: data/23191.jpg
#   inflating: data/23162.jpg
#   inflating: data/23174.jpg
#   inflating: data/23151.jpg
#   inflating: data/23182.jpg
#   inflating: data/23175.jpg
#   inflating: data/23149.jpg
#   inflating: data/23181.jpg
#   inflating: data/23155.jpg
#   inflating: data/23161.jpg
#   inflating: data/23282.jpg
#   inflating: data/23172.jpg
#   inflating: data/23164.jpg
#   inflating: data/23124.jpg
#   inflating: data/23143.jpg
#   inflating: data/23163.jpg
#   inflating: data/23157.jpg
#   inflating: data/23153.jpg
#   inflating: data/23159.jpg
#   inflating: data/23144.jpg
#   inflating: data/23150.jpg
#   inflating: data/23169.jpg
#   inflating: data/23137.jpg
#   inflating: data/23136.jpg
#   inflating: data/23156.jpg
#   inflating: data/23138.jpg
#   inflating: data/23139.jpg
#   inflating: data/23171.jpg
#   inflating: data/23166.jpg
#   inflating: data/23127.jpg
#   inflating: data/23154.jpg
#   inflating: data/23160.jpg
#   inflating: data/23123.jpg
#   inflating: data/23141.jpg
#   inflating: data/23122.jpg
#   inflating: data/23133.jpg
#   inflating: data/23126.jpg
#   inflating: data/23131.jpg
#   inflating: data/23093.jpg
#   inflating: data/23116.jpg
#   inflating: data/23135.jpg
#   inflating: data/23285.jpg
#   inflating: data/23103.jpg
#   inflating: data/23118.jpg
#   inflating: data/23130.jpg
#   inflating: data/23094.jpg
#   inflating: data/23125.jpg
#   inflating: data/23098.jpg
#   inflating: data/23088.jpg
#   inflating: data/23108.jpg
#   inflating: data/23117.jpg
#   inflating: data/23110.jpg
#   inflating: data/23100.jpg
#   inflating: data/23097.jpg
#   inflating: data/23109.jpg
#   inflating: data/23105.jpg
#   inflating: data/23114.jpg
#   inflating: data/23096.jpg
#   inflating: data/23072.jpg
#   inflating: data/23104.jpg
#   inflating: data/23068.jpg
#   inflating: data/23075.jpg
#   inflating: data/23073.jpg
#   inflating: data/23084.jpg
#   inflating: data/23101.jpg
#   inflating: data/23107.jpg
#   inflating: data/23102.jpg
#   inflating: data/23079.jpg
#   inflating: data/23087.jpg
#   inflating: data/23032.jpg
#   inflating: data/23023.jpg
#   inflating: data/23089.jpg
#   inflating: data/23070.jpg
#   inflating: data/23024.jpg
#   inflating: data/23106.jpg
#   inflating: data/23090.jpg
#   inflating: data/23012.jpg
#   inflating: data/23111.jpg
#   inflating: data/23048.jpg
#   inflating: data/23091.jpg
#   inflating: data/23044.jpg
#   inflating: data/23067.jpg
#   inflating: data/23051.jpg
#   inflating: data/23022.jpg
#   inflating: data/23053.jpg
#   inflating: data/23058.jpg
#   inflating: data/23026.jpg
#   inflating: data/23065.jpg
#   inflating: data/23060.jpg
#   inflating: data/23047.jpg
#   inflating: data/23055.jpg
#   inflating: data/23014.jpg
#   inflating: data/23033.jpg
#   inflating: data/23016.jpg
#   inflating: data/23042.jpg
#   inflating: data/23027.jpg
#   inflating: data/23041.jpg
#   inflating: data/23052.jpg
#   inflating: data/23049.jpg
#   inflating: data/23009.jpg
#   inflating: data/22988.jpg
#   inflating: data/23036.jpg
#   inflating: data/23018.jpg
#   inflating: data/23031.jpg
#   inflating: data/23037.jpg
#   inflating: data/23062.jpg
#   inflating: data/23003.jpg
#   inflating: data/22998.jpg
#   inflating: data/23040.jpg
#   inflating: data/22989.jpg
#   inflating: data/22990.jpg
#   inflating: data/23005.jpg
#   inflating: data/23004.jpg
#   inflating: data/22991.jpg
#   inflating: data/22983.jpg
#   inflating: data/22976.jpg
#   inflating: data/23001.jpg
#   inflating: data/22996.jpg
#   inflating: data/23008.jpg
#   inflating: data/22994.jpg
#   inflating: data/22992.jpg
#   inflating: data/22977.jpg
#   inflating: data/22997.jpg
#   inflating: data/22938.jpg
#   inflating: data/22982.jpg
#   inflating: data/22953.jpg
#   inflating: data/23002.jpg
#   inflating: data/22993.jpg
#   inflating: data/23061.jpg
#   inflating: data/22980.jpg
#   inflating: data/22978.jpg
#   inflating: data/22943.jpg
#   inflating: data/22973.jpg
#   inflating: data/22962.jpg
#   inflating: data/22955.jpg
#   inflating: data/22956.jpg
#   inflating: data/22967.jpg
#   inflating: data/22935.jpg
#   inflating: data/22954.jpg
#   inflating: data/22970.jpg
#   inflating: data/22986.jpg
#   inflating: data/22964.jpg
#   inflating: data/22961.jpg
#   inflating: data/22971.jpg
#   inflating: data/22944.jpg
#   inflating: data/22950.jpg
#   inflating: data/22947.jpg
#   inflating: data/22969.jpg
#   inflating: data/22948.jpg
#   inflating: data/22942.jpg
#   inflating: data/22960.jpg
#   inflating: data/22959.jpg
#   inflating: data/22952.jpg
#   inflating: data/22951.jpg
#   inflating: data/22949.jpg
#   inflating: data/22941.jpg
#   inflating: data/22908.jpg
#   inflating: data/22930.jpg
#   inflating: data/22966.jpg
#   inflating: data/22936.jpg
#   inflating: data/22987.jpg
#   inflating: data/22928.jpg
#   inflating: data/22899.jpg
#   inflating: data/22897.jpg
#   inflating: data/22934.jpg
#   inflating: data/22911.jpg
#   inflating: data/22900.jpg
#   inflating: data/22898.jpg
#   inflating: data/22921.jpg
#   inflating: data/22958.jpg
#   inflating: data/22924.jpg
#   inflating: data/23226.jpg
#   inflating: data/22920.jpg
#   inflating: data/22933.jpg
#   inflating: data/22903.jpg
#   inflating: data/22907.jpg
#   inflating: data/23148.jpg
#   inflating: data/23119.jpg
#   inflating: data/22974.jpg
#   inflating: data/23076.jpg
#   inflating: data/23185.jpg
#   inflating: data/22963.jpg
#   inflating: data/22995.jpg
#   inflating: data/23011.jpg
#   inflating: data/22925.jpg
#   inflating: data/22917.jpg
#   inflating: data/23228.jpg
#   inflating: data/22919.jpg
#   inflating: data/23045.jpg
#   inflating: data/22927.jpg
#   inflating: data/22890.jpg
#   inflating: data/22862.jpg
#   inflating: data/22884.jpg
#   inflating: data/22887.jpg
#   inflating: data/22879.jpg
#   inflating: data/22864.jpg
#   inflating: data/22869.jpg
#   inflating: data/22886.jpg
#   inflating: data/22915.jpg
#   inflating: data/22895.jpg
#   inflating: data/22877.jpg
#   inflating: data/22859.jpg
#   inflating: data/22860.jpg
#   inflating: data/22876.jpg
#   inflating: data/22912.jpg
#   inflating: data/22856.jpg
#   inflating: data/22868.jpg
#   inflating: data/22857.jpg
#   inflating: data/22885.jpg
#   inflating: data/22867.jpg
#   inflating: data/22881.jpg
#   inflating: data/22836.jpg
#   inflating: data/22837.jpg
#   inflating: data/22866.jpg
#   inflating: data/22882.jpg
#   inflating: data/22875.jpg
#   inflating: data/22821.jpg
#   inflating: data/22896.jpg
#   inflating: data/22883.jpg
#   inflating: data/22855.jpg
#   inflating: data/22817.jpg
#   inflating: data/22849.jpg
#   inflating: data/22814.jpg
#   inflating: data/22842.jpg
#   inflating: data/22834.jpg
#   inflating: data/22824.jpg
#   inflating: data/22822.jpg
#   inflating: data/22845.jpg
#   inflating: data/22846.jpg
#   inflating: data/22870.jpg
#   inflating: data/22848.jpg
#   inflating: data/22850.jpg
#   inflating: data/22847.jpg
#   inflating: data/22826.jpg
#   inflating: data/22832.jpg
#   inflating: data/22833.jpg
#   inflating: data/22843.jpg
#   inflating: data/22784.jpg
#   inflating: data/22830.jpg
#   inflating: data/22854.jpg
#   inflating: data/22790.jpg
#   inflating: data/22839.jpg
#   inflating: data/22827.jpg
#   inflating: data/22780.jpg
#   inflating: data/22823.jpg
#   inflating: data/22810.jpg
#   inflating: data/22820.jpg
#   inflating: data/22829.jpg
#   inflating: data/22813.jpg
#   inflating: data/22789.jpg
#   inflating: data/22799.jpg
#   inflating: data/22779.jpg
#   inflating: data/22809.jpg
#   inflating: data/22800.jpg
#   inflating: data/22786.jpg
#   inflating: data/22782.jpg
#   inflating: data/22807.jpg
#   inflating: data/22778.jpg
#   inflating: data/22736.jpg
#   inflating: data/22797.jpg
#   inflating: data/22818.jpg
#   inflating: data/22804.jpg
#   inflating: data/22776.jpg
#   inflating: data/22741.jpg
#   inflating: data/22759.jpg
#   inflating: data/22738.jpg
#   inflating: data/22745.jpg
#   inflating: data/22740.jpg
#   inflating: data/22766.jpg
#   inflating: data/22769.jpg
#   inflating: data/22747.jpg
#   inflating: data/22737.jpg
#   inflating: data/22765.jpg
#   inflating: data/22760.jpg
#   inflating: data/22755.jpg
#   inflating: data/22767.jpg
#   inflating: data/22753.jpg
#   inflating: data/22771.jpg
#   inflating: data/22754.jpg
#   inflating: data/22774.jpg
#   inflating: data/22761.jpg
#   inflating: data/22748.jpg
#   inflating: data/22746.jpg
#   inflating: data/22763.jpg
#   inflating: data/22777.jpg
#   inflating: data/22725.jpg
#   inflating: data/22775.jpg
#   inflating: data/22730.jpg
#   inflating: data/22727.jpg
#   inflating: data/22724.jpg
#   inflating: data/22720.jpg
#   inflating: data/22735.jpg
#   inflating: data/22734.jpg
#   inflating: data/22722.jpg
#   inflating: data/22852.jpg
#   inflating: data/22731.jpg
#   inflating: data/22732.jpg
#   inflating: data/22711.jpg
#   inflating: data/22705.jpg
#   inflating: data/22893.jpg
#   inflating: data/22858.jpg
#   inflating: data/22718.jpg
#   inflating: data/22709.jpg
#   inflating: data/22716.jpg
#   inflating: data/22913.jpg
#   inflating: data/22719.jpg
#   inflating: data/22891.jpg
#   inflating: data/22710.jpg
#   inflating: data/22706.jpg
#   inflating: data/22708.jpg
#   inflating: data/22707.jpg
#   inflating: data/22844.jpg
#   inflating: data/22687.jpg
#   inflating: data/22686.jpg
#   inflating: data/22717.jpg
#   inflating: data/22712.jpg
#   inflating: data/22690.jpg
#   inflating: data/22700.jpg
#   inflating: data/22696.jpg
#   inflating: data/22670.jpg
#   inflating: data/22679.jpg
#   inflating: data/22685.jpg
#   inflating: data/22673.jpg
#   inflating: data/22695.jpg
#   inflating: data/22681.jpg
#   inflating: data/22694.jpg
#   inflating: data/22669.jpg
#   inflating: data/22672.jpg
#   inflating: data/22683.jpg
#   inflating: data/22675.jpg
#   inflating: data/22688.jpg
#   inflating: data/22671.jpg
#   inflating: data/22801.jpg
#   inflating: data/22702.jpg
#   inflating: data/22819.jpg
#   inflating: data/22689.jpg
#   inflating: data/22676.jpg
#   inflating: data/22677.jpg
#   inflating: data/22666.jpg
#   inflating: data/22678.jpg
#   inflating: data/22871.jpg
#   inflating: data/22663.jpg
#   inflating: data/22703.jpg
#   inflating: data/22665.jpg
#   inflating: data/22691.jpg
#   inflating: data/22648.jpg
#   inflating: data/22723.jpg
#   inflating: data/22668.jpg
#   inflating: data/22629.jpg
#   inflating: data/22851.jpg
#   inflating: data/22660.jpg
#   inflating: data/22637.jpg
#   inflating: data/22647.jpg
#   inflating: data/22656.jpg
#   inflating: data/22644.jpg
#   inflating: data/22632.jpg
#   inflating: data/22631.jpg
#   inflating: data/22640.jpg
#   inflating: data/22653.jpg
#   inflating: data/22768.jpg
#   inflating: data/23286.jpg
#   inflating: data/22639.jpg
#   inflating: data/22650.jpg
#   inflating: data/22643.jpg
#   inflating: data/22642.jpg
#   inflating: data/22628.jpg
#   inflating: data/22811.jpg
#   inflating: data/22655.jpg
#   inflating: data/22657.jpg
#   inflating: data/22635.jpg
#   inflating: data/22602.jpg
#   inflating: data/22625.jpg
#   inflating: data/22646.jpg
#   inflating: data/22606.jpg
#   inflating: data/22636.jpg
#   inflating: data/22619.jpg
#   inflating: data/22721.jpg
#   inflating: data/22580.jpg
#   inflating: data/22812.jpg
#   inflating: data/22692.jpg
#   inflating: data/22589.jpg
#   inflating: data/22596.jpg
#   inflating: data/22614.jpg
#   inflating: data/22652.jpg
#   inflating: data/22585.jpg
#   inflating: data/23189.jpg
#   inflating: data/22593.jpg
#   inflating: data/22624.jpg
#   inflating: data/22597.jpg
#   inflating: data/22583.jpg
#   inflating: data/22588.jpg
#   inflating: data/22699.jpg
#   inflating: data/22664.jpg
#   inflating: data/22609.jpg
#   inflating: data/22600.jpg
#   inflating: data/22620.jpg
#   inflating: data/22633.jpg
#   inflating: data/22581.jpg
#   inflating: data/22623.jpg
#   inflating: data/22616.jpg
#   inflating: data/22626.jpg
#   inflating: data/22595.jpg
#   inflating: data/22598.jpg
#   inflating: data/22608.jpg
#   inflating: data/23167.jpg
#   inflating: data/22634.jpg
#   inflating: data/22586.jpg
#   inflating: data/22617.jpg
#   inflating: data/22553.jpg
#   inflating: data/22563.jpg
#   inflating: data/22539.jpg
#   inflating: data/22537.jpg
#   inflating: data/22543.jpg
#   inflating: data/22555.jpg
#   inflating: data/22546.jpg
#   inflating: data/22592.jpg
#   inflating: data/22574.jpg
#   inflating: data/22545.jpg
#   inflating: data/22661.jpg
#   inflating: data/22540.jpg
#   inflating: data/22587.jpg
#   inflating: data/22542.jpg
#   inflating: data/22538.jpg
#   inflating: data/22558.jpg
#   inflating: data/22577.jpg
#   inflating: data/22576.jpg
#   inflating: data/22603.jpg
#   inflating: data/22570.jpg
#   inflating: data/22568.jpg
#   inflating: data/22764.jpg
#   inflating: data/22742.jpg
#   inflating: data/23069.jpg
#   inflating: data/22552.jpg
#   inflating: data/23006.jpg
#   inflating: data/22550.jpg
#   inflating: data/22572.jpg
#   inflating: data/22654.jpg
#   inflating: data/22965.jpg
#   inflating: data/22528.jpg
#   inflating: data/22562.jpg
#   inflating: data/22557.jpg
#   inflating: data/22569.jpg
#   inflating: data/22575.jpg
#   inflating: data/22518.jpg
#   inflating: data/22508.jpg
#   inflating: data/22556.jpg
#   inflating: data/22511.jpg
#   inflating: data/22564.jpg
#   inflating: data/22526.jpg
#   inflating: data/22514.jpg
#   inflating: data/22520.jpg
#   inflating: data/22506.jpg
#   inflating: data/22517.jpg
#   inflating: data/22512.jpg
#   inflating: data/22525.jpg
#   inflating: data/22516.jpg
# ...
#   inflating: data/20643.jpg
#   inflating: data/20628.jpg
#   inflating: data/20634.jpg
#   inflating: data/20642.jpg
#   inflating: data/20631.jpg
#   inflating: data/20635.jpg
#   inflating: data/20630.jpg
#   inflating: data/20637.jpg
#   inflating: data/20616.jpg
#   inflating: data/20621.jpg
#   inflating: data/20638.jpg
#   inflating: data/20629.jpg
#   inflating: data/20615.jpg
#   inflating: data/20761.jpg
#   inflating: data/20633.jpg
#   inflating: data/20620.jpg
#   inflating: data/20639.jpg
#   inflating: data/20590.jpg
#   inflating: data/20581.jpg
#   inflating: data/20622.jpg
#   inflating: data/20592.jpg
#   inflating: data/20587.jpg
#   inflating: data/20626.jpg
#   inflating: data/20608.jpg
#   inflating: data/20571.jpg
#   inflating: data/20599.jpg
#   inflating: data/20640.jpg
#   inflating: data/20606.jpg
#   inflating: data/20595.jpg
#   inflating: data/20603.jpg
#   inflating: data/20589.jpg
#   inflating: data/20611.jpg
#   inflating: data/20570.jpg
#   inflating: data/20601.jpg
#   inflating: data/20613.jpg
#   inflating: data/20598.jpg
#   inflating: data/20585.jpg
#   inflating: data/20597.jpg
#   inflating: data/20605.jpg
#   inflating: data/20584.jpg
#   inflating: data/20545.jpg
#   inflating: data/20574.jpg
#   inflating: data/20577.jpg
#   inflating: data/20728.jpg
#   inflating: data/20575.jpg
#   inflating: data/20580.jpg
#   inflating: data/20602.jpg
#   inflating: data/20558.jpg
#   inflating: data/20576.jpg
#   inflating: data/20582.jpg
#   inflating: data/20539.jpg
#   inflating: data/20554.jpg
#   inflating: data/20546.jpg
#   inflating: data/20533.jpg
#   inflating: data/20531.jpg
#   inflating: data/20568.jpg
#   inflating: data/20535.jpg
#   inflating: data/20537.jpg
#   inflating: data/20561.jpg
#   inflating: data/20541.jpg
#   inflating: data/20612.jpg
#   inflating: data/20566.jpg
#   inflating: data/20530.jpg
#   inflating: data/20556.jpg
#   inflating: data/20591.jpg
#   inflating: data/20664.jpg
#   inflating: data/20534.jpg
#   inflating: data/20564.jpg
#   inflating: data/20550.jpg
#   inflating: data/20559.jpg
#   inflating: data/20510.jpg
#   inflating: data/20544.jpg
#   inflating: data/20567.jpg
#   inflating: data/20504.jpg
#   inflating: data/20549.jpg
#   inflating: data/20517.jpg
#   inflating: data/20528.jpg
#   inflating: data/20494.jpg
#   inflating: data/20560.jpg
#   inflating: data/20480.jpg
#   inflating: data/20477.jpg
#   inflating: data/20508.jpg
#   inflating: data/20511.jpg
#   inflating: data/20512.jpg
#   inflating: data/20536.jpg
#   inflating: data/20524.jpg
#   inflating: data/20516.jpg
#   inflating: data/20519.jpg
#   inflating: data/20520.jpg
#   inflating: data/20487.jpg
#   inflating: data/20553.jpg
#   inflating: data/20490.jpg
#   inflating: data/20527.jpg
#   inflating: data/20660.jpg
#   inflating: data/20484.jpg
#   inflating: data/20497.jpg
#   inflating: data/20495.jpg
#   inflating: data/20482.jpg
#   inflating: data/20485.jpg
#   inflating: data/20522.jpg
#   inflating: data/20498.jpg
#   inflating: data/20458.jpg
#   inflating: data/20444.jpg
#   inflating: data/20435.jpg
#   inflating: data/20472.jpg
#   inflating: data/20447.jpg
#   inflating: data/20479.jpg
#   inflating: data/20476.jpg
#   inflating: data/20687.jpg
#   inflating: data/20619.jpg
#   inflating: data/20565.jpg
#   inflating: data/20439.jpg
#   inflating: data/20438.jpg
#   inflating: data/20440.jpg
#   inflating: data/20460.jpg
#   inflating: data/20449.jpg
#   inflating: data/20475.jpg
#   inflating: data/20454.jpg
#   inflating: data/20473.jpg
#   inflating: data/20465.jpg
#   inflating: data/20756.jpg
#   inflating: data/20467.jpg
#   inflating: data/20596.jpg
#   inflating: data/20433.jpg
#   inflating: data/20443.jpg
#   inflating: data/20572.jpg
#   inflating: data/20540.jpg
#   inflating: data/20450.jpg
#   inflating: data/20459.jpg
#   inflating: data/20455.jpg
#   inflating: data/20413.jpg
#   inflating: data/20430.jpg
#   inflating: data/20406.jpg
#   inflating: data/20436.jpg
#   inflating: data/20515.jpg
#   inflating: data/20432.jpg
#   inflating: data/20464.jpg
#   inflating: data/20617.jpg
#   inflating: data/20427.jpg
#   inflating: data/20405.jpg
#   inflating: data/20448.jpg
#   inflating: data/20446.jpg
#   inflating: data/20400.jpg
#   inflating: data/20414.jpg
#   inflating: data/20493.jpg
#   inflating: data/20390.jpg
#   inflating: data/20563.jpg
#   inflating: data/20392.jpg
#   inflating: data/20423.jpg
#   inflating: data/20431.jpg
#   inflating: data/20502.jpg
#   inflating: data/20394.jpg
#   inflating: data/20425.jpg
#   inflating: data/20663.jpg
#   inflating: data/20424.jpg
#   inflating: data/20489.jpg
#   inflating: data/20408.jpg
#   inflating: data/20397.jpg
#   inflating: data/20402.jpg
#   inflating: data/20491.jpg
#   inflating: data/20398.jpg
#   inflating: data/20474.jpg
#   inflating: data/20461.jpg
#   inflating: data/20409.jpg
#   inflating: data/20586.jpg
#   inflating: data/20457.jpg
#   inflating: data/20421.jpg
#   inflating: data/20555.jpg
#   inflating: data/20513.jpg
#   inflating: data/20378.jpg
#   inflating: data/20362.jpg
#   inflating: data/20383.jpg
#   inflating: data/20374.jpg
#   inflating: data/20389.jpg
#   inflating: data/20333.jpg
#   inflating: data/20419.jpg
#   inflating: data/20418.jpg
#   inflating: data/20365.jpg
#   inflating: data/20416.jpg
#   inflating: data/20373.jpg
#   inflating: data/20393.jpg
#   inflating: data/20379.jpg
#   inflating: data/20353.jpg
#   inflating: data/20395.jpg
#   inflating: data/20386.jpg
#   inflating: data/20382.jpg
#   inflating: data/20352.jpg
#   inflating: data/20372.jpg
#   inflating: data/20356.jpg
#   inflating: data/20367.jpg
#   inflating: data/20417.jpg
#   inflating: data/20341.jpg
#   inflating: data/20344.jpg
#   inflating: data/20357.jpg
#   inflating: data/20384.jpg
#   inflating: data/20486.jpg
#   inflating: data/20359.jpg
#   inflating: data/20342.jpg
#   inflating: data/20388.jpg
#   inflating: data/20346.jpg
#   inflating: data/20327.jpg
#   inflating: data/20371.jpg
#   inflating: data/20348.jpg
#   inflating: data/20331.jpg
#   inflating: data/20334.jpg
#   inflating: data/20332.jpg
#   inflating: data/20411.jpg
#   inflating: data/20363.jpg
#   inflating: data/20306.jpg
#   inflating: data/20366.jpg
#   inflating: data/20370.jpg
#   inflating: data/20345.jpg
#   inflating: data/20337.jpg
#   inflating: data/20336.jpg
#   inflating: data/20317.jpg
#   inflating: data/20358.jpg
#   inflating: data/20387.jpg
#   inflating: data/20315.jpg
#   inflating: data/20319.jpg
#   inflating: data/20305.jpg
#   inflating: data/20343.jpg
#   inflating: data/20307.jpg
#   inflating: data/20310.jpg
#   inflating: data/20311.jpg
#   inflating: data/20316.jpg
#   inflating: data/20297.jpg
#   inflating: data/20314.jpg
#   inflating: data/20271.jpg
#   inflating: data/20273.jpg
#   inflating: data/20292.jpg
#   inflating: data/20299.jpg
#   inflating: data/20300.jpg
#   inflating: data/20303.jpg
#   inflating: data/20350.jpg
#   inflating: data/20285.jpg
#   inflating: data/20274.jpg
#   inflating: data/20322.jpg
#   inflating: data/20318.jpg
#   inflating: data/20304.jpg
#   inflating: data/20329.jpg
#   inflating: data/20281.jpg
#   inflating: data/20270.jpg
#   inflating: data/20326.jpg
#   inflating: data/20267.jpg
#   inflating: data/20293.jpg
#   inflating: data/20288.jpg
#   inflating: data/20269.jpg
#   inflating: data/20282.jpg
#   inflating: data/20268.jpg
#   inflating: data/20294.jpg
#   inflating: data/20276.jpg
#   inflating: data/20272.jpg
#   inflating: data/20380.jpg
#   inflating: data/20226.jpg
#   inflating: data/20286.jpg
#   inflating: data/20246.jpg
#   inflating: data/20241.jpg
#   inflating: data/20257.jpg
#   inflating: data/20234.jpg
#   inflating: data/20265.jpg
#   inflating: data/20230.jpg
#   inflating: data/20287.jpg
#   inflating: data/20296.jpg
#   inflating: data/20253.jpg
#   inflating: data/20232.jpg
#   inflating: data/20252.jpg
#   inflating: data/20236.jpg
#   inflating: data/20347.jpg
#   inflating: data/20243.jpg
#   inflating: data/20247.jpg
#   inflating: data/20229.jpg
#   inflating: data/20238.jpg
#   inflating: data/20328.jpg
#   inflating: data/20264.jpg
#   inflating: data/20261.jpg
#   inflating: data/20266.jpg
#   inflating: data/20256.jpg
#   inflating: data/20240.jpg
#   inflating: data/20255.jpg
#   inflating: data/20228.jpg
#   inflating: data/20221.jpg
#   inflating: data/20227.jpg
#   inflating: data/20245.jpg
#   inflating: data/20212.jpg
#   inflating: data/20206.jpg
#   inflating: data/20191.jpg
#   inflating: data/20185.jpg
#   inflating: data/20210.jpg
#   inflating: data/20202.jpg
#   inflating: data/20198.jpg
#   inflating: data/20209.jpg
#   inflating: data/20195.jpg
#   inflating: data/20320.jpg
#   inflating: data/20186.jpg
#   inflating: data/20183.jpg
#   inflating: data/20187.jpg
#   inflating: data/20277.jpg
#   inflating: data/20207.jpg
#   inflating: data/20225.jpg
#   inflating: data/20289.jpg
#   inflating: data/20218.jpg
#   inflating: data/20189.jpg
#   inflating: data/20178.jpg
#   inflating: data/20216.jpg
#   inflating: data/20165.jpg
#   inflating: data/20164.jpg
#   inflating: data/20171.jpg
#   inflating: data/20176.jpg
#   inflating: data/20162.jpg
#   inflating: data/20441.jpg
#   inflating: data/20174.jpg
#   inflating: data/20168.jpg
#   inflating: data/20211.jpg
#   inflating: data/20231.jpg
#   inflating: data/20166.jpg
#   inflating: data/20167.jpg
#   inflating: data/20163.jpg
#   inflating: data/20250.jpg
#   inflating: data/20172.jpg
#   inflating: data/20177.jpg
#   inflating: data/20161.jpg
#   inflating: data/20173.jpg
#   inflating: data/20154.jpg
#   inflating: data/20158.jpg
#   inflating: data/20136.jpg
#   inflating: data/20142.jpg
#   inflating: data/20137.jpg
#   inflating: data/20249.jpg
#   inflating: data/20138.jpg
#   inflating: data/20152.jpg
#   inflating: data/20153.jpg
#   inflating: data/20150.jpg
#   inflating: data/20184.jpg
#   inflating: data/20160.jpg
#   inflating: data/20140.jpg
#   inflating: data/20133.jpg
#   inflating: data/20134.jpg
#   inflating: data/20144.jpg
#   inflating: data/20098.jpg
#   inflating: data/20100.jpg
#   inflating: data/20260.jpg
#   inflating: data/20179.jpg
#   inflating: data/20159.jpg
#   inflating: data/20126.jpg
#   inflating: data/20151.jpg
#   inflating: data/20112.jpg
#   inflating: data/20127.jpg
#   inflating: data/20107.jpg
#   inflating: data/20093.jpg
#   inflating: data/20108.jpg
#   inflating: data/20095.jpg
#   inflating: data/20094.jpg
#   inflating: data/20109.jpg
#   inflating: data/20401.jpg
#   inflating: data/20111.jpg
#   inflating: data/20181.jpg
#   inflating: data/20124.jpg
#   inflating: data/20113.jpg
#   inflating: data/20096.jpg
#   inflating: data/20120.jpg
#   inflating: data/20313.jpg
#   inflating: data/20131.jpg
#   inflating: data/20106.jpg
#   inflating: data/20115.jpg
#   inflating: data/20114.jpg
#   inflating: data/20080.jpg
#   inflating: data/20082.jpg
#   inflating: data/20076.jpg
#   inflating: data/20123.jpg
#   inflating: data/20073.jpg
#   inflating: data/20116.jpg
#   inflating: data/20283.jpg
#   inflating: data/20084.jpg
#   inflating: data/20078.jpg
#   inflating: data/20077.jpg
#   inflating: data/20087.jpg
#   inflating: data/20081.jpg
#   inflating: data/20089.jpg
#   inflating: data/20088.jpg
#   inflating: data/20090.jpg
#   inflating: data/20079.jpg
#   inflating: data/20083.jpg
#   inflating: data/20059.jpg
#   inflating: data/20072.jpg
#   inflating: data/20069.jpg
#   inflating: data/20070.jpg
#   inflating: data/20067.jpg
#   inflating: data/20074.jpg
#   inflating: data/20330.jpg
#   inflating: data/20064.jpg
#   inflating: data/20058.jpg
#   inflating: data/20222.jpg
#   inflating: data/20057.jpg
#   inflating: data/20068.jpg
#   inflating: data/20129.jpg
#   inflating: data/20060.jpg
#   inflating: data/20056.jpg
#   inflating: data/20148.jpg
#   inflating: data/20259.jpg
#   inflating: data/20190.jpg
#   inflating: data/20147.jpg
#   inflating: data/20091.jpg
#   inflating: data/20204.jpg
#   inflating: data/20117.jpg
#   inflating: data/20242.jpg
#   inflating: data/20170.jpg
#   inflating: data/20075.jpg
#   inflating: data/20335.jpg
#   inflating: data/20275.jpg
#   inflating: data/20194.jpg
#   inflating: data/20061.jpg
#   inflating: data/20355.jpg
#   inflating: data/20157.jpg
#   inflating: data/20175.jpg
#   inflating: data/20099.jpg
#   inflating: data/20071.jpg
#   inflating: data/20066.jpg
#   inflating: data/20309.jpg
#   inflating: data/20092.jpg
#   inflating: data/20062.jpg
#   inflating: data/20085.jpg

# %%
from PIL import Image
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from matplotlib import image
from matplotlib import pyplot as plt
import os
from tensorflow import keras
import argparse
import cv2

# %%
dataset_split = 2500

master_dir = 'data'
lr_list = []
hr_list = []
for image_file in os.listdir( master_dir )[ 0 : dataset_split ]:
    hr = Image.open( os.path.join( master_dir , image_file ) ).resize( ( 128 , 128 ) )
    hr=np.asarray(hr)
    #hr = cv2.cvtColor(hr, cv2.COLOR_BGR2RGB)
    #lr = cv2.cvtColor(lr, cv2.COLOR_BGR2RGB)
    lr= Image.open( os.path.join( master_dir , image_file ) ).resize( ( 32 , 32 ) ) 
    lr = lr.convert( 'L' )
    lr=np.asarray(lr)
    hr_list.append(hr)
    lr_list.append(lr)

lr_list = np.array(lr_list)
hr_list = np.array(hr_list)

# %%
lr_images=lr_list
hr_images=hr_list


#Scale values
lr_images = lr_images / 255.
hr_images = hr_images / 255.

#Split to train and test
lr_train, lr_test, hr_train, hr_test = train_test_split(lr_images, hr_images, 
                                                      test_size=0.33, random_state=42)

lr_train = np.repeat(lr_train[..., np.newaxis], 3, -1)
print(lr_train.shape)
lr_test = np.repeat(lr_test[..., np.newaxis], 3, -1)


hr_shape = (hr_train.shape[1], hr_train.shape[2], hr_train.shape[3])
lr_shape = (lr_train.shape[1], lr_train.shape[2], lr_train.shape[3])

lr_ip = Input(shape=lr_shape)
hr_ip = Input(shape=hr_shape)

# %%
#########################################################################

#Define blocks to build the generator
def res_block(ip):
    
    res_model = Conv2D(64, (3,3), padding = "same")(ip)
    res_model = BatchNormalization(momentum = 0.5)(res_model)
    res_model = PReLU(shared_axes = [1,2])(res_model)
    
    res_model = Conv2D(64, (3,3), padding = "same")(res_model)
    res_model = BatchNormalization(momentum = 0.5)(res_model)
    
    return add([ip,res_model])

def upscale_block(ip):
    
    up_model = Conv2D(256, (3,3), padding="same")(ip)
    up_model = UpSampling2D( size = 2 )(up_model)
    up_model = PReLU(shared_axes=[1,2])(up_model)
    
    return up_model

#Generator model
def create_gen(gen_ip, num_res_block):
    layers = Conv2D(64, (9,9), padding="same")(gen_ip)
    layers = PReLU(shared_axes=[1,2])(layers)

    temp = layers

    for i in range(num_res_block):
        layers = res_block(layers)

    layers = Conv2D(64, (3,3), padding="same")(layers)
    layers = BatchNormalization(momentum=0.5)(layers)
    layers = add([layers,temp])

    layers = upscale_block(layers)
    layers = upscale_block(layers)

    op = Conv2D(3, (9,9), padding="same")(layers)

    return Model(inputs=gen_ip, outputs=op)

#Descriminator block that will be used to construct the discriminator
def discriminator_block(ip, filters, strides=1, bn=True):
    
    disc_model = Conv2D(filters, (3,3), strides = strides, padding="same")(ip)
    
    if bn:
        disc_model = BatchNormalization( momentum=0.8 )(disc_model)
    
    disc_model = LeakyReLU( alpha=0.2 )(disc_model)
    
    return disc_model

def create_disc(disc_ip):

    df = 64
    
    d1 = discriminator_block(disc_ip, df, bn=False)
    d2 = discriminator_block(d1, df, strides=2)
    d3 = discriminator_block(d2, df*2)
    d4 = discriminator_block(d3, df*2, strides=2)
    d5 = discriminator_block(d4, df*4)
    d6 = discriminator_block(d5, df*4, strides=2)
    d7 = discriminator_block(d6, df*8)
    d8 = discriminator_block(d7, df*8, strides=2)
    
    d8_5 = Flatten()(d8)
    d9 = Dense(df*16)(d8_5)
    d10 = LeakyReLU(alpha=0.2)(d9)
    validity = Dense(1, activation='sigmoid')(d10)

    return Model(disc_ip, validity)

# %%
from keras.applications.vgg19 import VGG19

def build_vgg(hr_shape):
    
    vgg = VGG19(weights="imagenet",include_top=False, input_shape=hr_shape)
    
    return Model(inputs=vgg.inputs, outputs=vgg.layers[10].output)

# %%
#Combined model
def create_comb(gen_model, disc_model, vgg, lr_ip, hr_ip):
    gen_img = gen_model(lr_ip)
    
    gen_features = vgg(gen_img)
    
    disc_model.trainable = False
    validity = disc_model(gen_img)
    
    return Model(inputs=[lr_ip, hr_ip], outputs=[validity, gen_features])

# %%
plt.figure(figsize=(10,10))
or_image = plt.subplot(3,3,1)
or_image.set_title('Grayscale Input', fontsize=16)
plt.imshow(lr_test[0] , cmap='gray' )

ou_image = plt.subplot(3,3,3)
image = Image.fromarray( ( hr_test[0] * 255 ).astype( 'uint8' ) ).resize( ( 1024 , 1024 ) )
ou_image.set_title('Ground Truth', fontsize=16)
plt.imshow( image )

# %%
generator = create_gen(lr_ip, num_res_block = 16)
generator.summary()

discriminator = create_disc(hr_ip)
discriminator.compile(loss="binary_crossentropy", optimizer="adam", metrics=['accuracy'])
discriminator.summary()

vgg = build_vgg((128,128,3))
print(vgg.summary())
vgg.trainable = False

gan_model = create_comb(generator, discriminator, vgg, lr_ip, hr_ip)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 64)   15616       ['input_1[0][0]']
#
#  p_re_lu (PReLU)                (None, 32, 32, 64)   64          ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 64)   36928       ['p_re_lu[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['conv2d_1[0][0]']
#  alization)
#
#  p_re_lu_1 (PReLU)              (None, 32, 32, 64)   64          ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   36928       ['p_re_lu_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 64)   0           ['p_re_lu[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36928       ['add[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  p_re_lu_2 (PReLU)              (None, 32, 32, 64)   64          ['batch_normalization_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   36928       ['p_re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 64)   0           ['add[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   36928       ['add_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  p_re_lu_3 (PReLU)              (None, 32, 32, 64)   64          ['batch_normalization_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 64)   36928       ['p_re_lu_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 64)   0           ['add_1[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 64)   36928       ['add_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  p_re_lu_4 (PReLU)              (None, 32, 32, 64)   64          ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 64)   36928       ['p_re_lu_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 32, 32, 64)   0           ['add_2[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 64)   36928       ['add_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  p_re_lu_5 (PReLU)              (None, 32, 32, 64)   64          ['batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_5[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_10[0][0]']
#  rmalization)
#
#  add_4 (Add)                    (None, 32, 32, 64)   0           ['add_3[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 64)   36928       ['add_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  p_re_lu_6 (PReLU)              (None, 32, 32, 64)   64          ['batch_normalization_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_6[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 32, 32, 64)   0           ['add_4[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   36928       ['add_5[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  p_re_lu_7 (PReLU)              (None, 32, 32, 64)   64          ['batch_normalization_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_7[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 32, 64)   0           ['add_5[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   36928       ['add_6[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  p_re_lu_8 (PReLU)              (None, 32, 32, 64)   64          ['batch_normalization_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_8[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 32, 32, 64)   0           ['add_6[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 64)   36928       ['add_7[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  p_re_lu_9 (PReLU)              (None, 32, 32, 64)   64          ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_9[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 32, 32, 64)   0           ['add_7[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   36928       ['add_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  p_re_lu_10 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_10[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 32, 32, 64)   0           ['add_8[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 64)   36928       ['add_9[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  p_re_lu_11 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_11[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 64)  256         ['conv2d_22[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 32, 32, 64)   0           ['add_9[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 64)   36928       ['add_10[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  p_re_lu_12 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_12[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 32, 32, 64)   0           ['add_10[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 64)   36928       ['add_11[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  p_re_lu_13 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_13[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 32, 32, 64)   0           ['add_11[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 64)   36928       ['add_12[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  p_re_lu_14 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_14[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 32, 32, 64)   0           ['add_12[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 64)   36928       ['add_13[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 64)  256         ['conv2d_29[0][0]']
#  ormalization)
#
#  p_re_lu_15 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_15[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 64)  256         ['conv2d_30[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 32, 32, 64)   0           ['add_13[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 64)   36928       ['add_14[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  p_re_lu_16 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_16[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 64)  256         ['conv2d_32[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 32, 32, 64)   0           ['add_14[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 64)   36928       ['add_15[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 64)  256         ['conv2d_33[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_32[0][0]',
#                                                                   'p_re_lu[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 256)  147712      ['add_16[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 256)  0           ['conv2d_34[0][0]']
#
#  p_re_lu_17 (PReLU)             (None, 64, 64, 256)  256         ['up_sampling2d[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 64, 64, 256)  590080      ['p_re_lu_17[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 25  0          ['conv2d_35[0][0]']
#                                 6)
#
#  p_re_lu_18 (PReLU)             (None, 128, 128, 25  256         ['up_sampling2d_1[0][0]']
#                                 6)
#
#  conv2d_36 (Conv2D)             (None, 128, 128, 3)  62211       ['p_re_lu_18[0][0]']
#
# ==================================================================================================
# Total params: 2,044,291
# Trainable params: 2,040,067
# Non-trainable params: 4,224
# __________________________________________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv2d_37 (Conv2D)          (None, 128, 128, 64)      1792
#
#  leaky_re_lu (LeakyReLU)     (None, 128, 128, 64)      0
#
#  conv2d_38 (Conv2D)          (None, 64, 64, 64)        36928
#
#  batch_normalization_33 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 64)        0
#
#  conv2d_39 (Conv2D)          (None, 64, 64, 128)       73856
#
#  batch_normalization_34 (Bat  (None, 64, 64, 128)      512
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 64, 64, 128)       0
#
#  conv2d_40 (Conv2D)          (None, 32, 32, 128)       147584
#
#  batch_normalization_35 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 256)       295168
#
#  batch_normalization_36 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_42 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_37 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  conv2d_43 (Conv2D)          (None, 16, 16, 512)       1180160
#
#  batch_normalization_38 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 16, 16, 512)       0
#
#  conv2d_44 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  batch_normalization_39 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 1024)              33555456
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 38,249,281
# Trainable params: 38,245,569
# Non-trainable params: 3,712
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 32, 32, 256)       590080
#
# =================================================================
# Total params: 2,325,568
# Trainable params: 2,325,568
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
gan_model.compile(loss=["binary_crossentropy", "mse"], loss_weights=[1e-3, 1], optimizer="adam")
gan_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  model (Functional)             (None, 128, 128, 3)  2044291     ['input_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  model_1 (Functional)           (None, 1)            38249281    ['model[0][0]']
#
#  model_2 (Functional)           (None, 32, 32, 256)  2325568     ['model[0][0]']
#
# ==================================================================================================
# Total params: 42,619,140
# Trainable params: 2,040,067
# Non-trainable params: 40,579,073
# __________________________________________________________________________________________________

# %%
batch_size = 1  
train_lr_batches = []
train_hr_batches = []
for it in range(int(hr_train.shape[0] / batch_size)):
    start_idx = it * batch_size
    end_idx = start_idx + batch_size
    train_hr_batches.append(hr_train[start_idx:end_idx])
    train_lr_batches.append(lr_train[start_idx:end_idx])
    
    
epochs = 20
#Enumerate training over epochs
for e in range(epochs):
    
    fake_label = np.zeros((batch_size, 1))
    real_label = np.ones((batch_size,1)) 
    
    #Create empty lists to populate gen and disc losses. 
    g_losses = []
    d_losses = []
    
    #Enumerate training over batches. 
    for b in tqdm(range(len(train_hr_batches))):
        lr_imgs = train_lr_batches[b] 
        hr_imgs = train_hr_batches[b] 
        
        fake_imgs = generator.predict_on_batch(lr_imgs) #Fake images
        

        discriminator.trainable = True
        d_loss_gen = discriminator.train_on_batch(fake_imgs, fake_label)
        d_loss_real = discriminator.train_on_batch(hr_imgs, real_label)
        
  
        discriminator.trainable = False
        

        d_loss = 0.5 * np.add(d_loss_gen, d_loss_real) 
        
  
        image_features = vgg.predict(hr_imgs)
     

        g_loss, _, _ = gan_model.train_on_batch([lr_imgs, hr_imgs], [real_label, image_features])
        

        d_losses.append(d_loss)
        g_losses.append(g_loss)
        
   
    g_losses = np.array(g_losses)
    d_losses = np.array(d_losses)
    

    g_loss = np.sum(g_losses, axis=0) / len(g_losses)
    d_loss = np.sum(d_losses, axis=0) / len(d_losses)
    
 
    print("epoch:", e+1 ,"g_loss:", g_loss, "d_loss:", d_loss)

    if (e+1) % 10 == 0: 

        generator.save("gen_e_"+ str(e+1) +".h5")

# %%
generator.save("/content/drive/MyDrive/srganmodel20.h5")

# %%
from numpy import loadtxt
from tensorflow.keras.models import load_model
generator = load_model("/content/drive/MyDrive/srganmodel20.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from keras.models import load_model
from numpy.random import randint



[X1, X2] = [lr_test, hr_test]


ix = randint(0, len(X1), 1)
src_image, tar_image = X1[ix], X2[ix]


gen_image = generator.predict(src_image)



# plot all three images

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('LR Image')
plt.imshow(src_image[0,:,:,:])
plt.subplot(232)
plt.title('Superresolution')
plt.imshow(gen_image[0,:,:,:])
plt.subplot(233)
plt.title('Orig. HR image')
plt.imshow(tar_image[0,:,:,:])

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# FUNCTION TO TAKE CUSTOM INPUT

# %%
from keras.models import load_model
from numpy.random import randint

def preprocess():
  custom_list = []
  orig_list = []

  orig= Image.open('/content/scenery.jpeg').resize( ( 128 , 128 ) )
  orig=np.asarray(orig)

  custom= Image.open('/content/scenery.jpeg').resize( ( 32 , 32 ) ) 
  custom = custom.convert( 'L' )

  custom=np.asarray(custom)
  orig_list.append(orig)
  custom_list.append(custom)

  custom_list = np.array(custom_list)
  orig_list = np.array(orig_list)


  custom_images=custom_list
  orig_images=orig_list


  #Scale values
  custom_images = custom_images / 255.
  orig_images = orig_images / 255.


  custom_images = np.repeat(custom_images[..., np.newaxis], 3, -1)


  [X1, X2] = [custom_images, orig_images]


  ix = randint(0, len(X1), 1)
  src_image, tar_image = X1[ix], X2[ix]


  gen_image = generator.predict(src_image)



  # plot all three images

  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.title('LR Image')
  plt.imshow(src_image[0,:,:,:])
  plt.subplot(232)
  plt.title('Superresolution')
  plt.imshow(gen_image[0,:,:,:])
  plt.subplot(233)
  plt.title('Orig. HR image')
  plt.imshow(tar_image[0,:,:,:])

  plt.show()

# %%
preprocess()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
